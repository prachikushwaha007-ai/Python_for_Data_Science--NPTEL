# %% [markdown]
# <a href="https://colab.research.google.com/github/prachikushwaha007-ai/Python_for_Data_Science--NPTEL/blob/main/1_NPTEL_5_variable_datatype.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Employee_name="Ram"
Age=55
Height=150.6
type(Height) is int
# Out:
# False

# %%
type(Age) is float
# Out:
# False

# %%
type (Employee_name) is str
# Out:
# True

# %%
type(Height)
# Out:
# float

# %%
ht=int(Height)

# %%
type(ht)
# Out:
# int

# %%
Height=int(ht)

# %%
# NPTEL.6
A=7-2*(27/3**2)+4
print(A)
# Out:
# 5.0

# %%
a=10
b=5
a+=b
print(a)
# Out:
# 15

# %%
a=10
b=5
a-=b
print(a)
# Out:
# 5

# %%
a=10
b=5
a*=b
print(a)
# Out:
# 50

# %%
a/=b
print (a)
# Out:
# 10.0

# %%
# Relational or comparison operators
x=5
y=7
print (x<y)
# Out:
# True

# %%
print (x<=y)
# Out:
# True

# %%
print (x==y)
# Out:
# False

# %%
print(x!=y)
# Out:
# True

# %%
#Logical operators
print (x<y) or (x>y)
# Out:
# True
# False

# %%
#or
print ((x<y) or (x>y))
# Out:
# True

# %%
#and
print ((x<y) and (x>y))
# Out:
# False

# %%
#not
print (not (x==y))
# Out:
# True

# %%
# Bitwise operators (|, &):integers as string of binary digits.
x=5
y=7
x|y
# Out:
# 7

# %%
print ((x<y)|(x==y))
# Out:
# True

# %%
# assignment
a=3
b="12"
print (a*b)
# Out:
# 121212
