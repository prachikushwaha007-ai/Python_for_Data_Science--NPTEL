# %% [markdown]
# <a href="https://colab.research.google.com/github/prachikushwaha007-ai/Python_for_Data_Science--NPTEL/blob/main/3_Sequence_Data_Indexing_NPTEL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ARRAY* MODULE[ [STORES SAME TYPE OF DATA]
from array  import*
arrsample = array('f', [1.0,2.0,3.0,.04])
for x in arrsample :
  print (x)
# Out:
# 1.0
# 2.0
# 3.0
# 0.03999999910593033

# %%
arr = array('f', [1,2,3,4,7,5])
for y in arr: print (y)
# Out:
# 1.0
# 2.0
# 3.0
# 4.0
# 7.0
# 5.0

# %%
#SOME ERRORS
int('hello')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2451/3401026459.py in <cell line: 0>()
#       1 #SOME ERRORS
# ----> 2 int('hello')
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
arr = array('i', [10,20,30])
arr.remove(50)

# %%
# Set
setsample = {'example', 24,87.5,'data',24,'data'}
setsample
set ('example')

# %%
# Range
range1= range(1,12,5)
print(range1)
for x in range1:
   print (x)

# %%
# indexing (o from starting & -1 from last position)
str = 'my name is prachi'
str[2]

# %%
str[-2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2451/1958312952.py in <cell line: 0>()
# ----> 1 str[-2]
#
# TypeError: type 'str' is not subscriptable

# %%
str[-9]

# %%
str.index('i')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2451/277172472.py in <cell line: 0>()
# ----> 1 str.index('i')
#
# TypeError: index() takes at least 1 argument (0 given)

# %%
# list: indexing
list = ['one', 1,2,3,5]
list[1]

# %%
list.index(5)

# %%
list[-1]

# %%
# Array : indexing
from array import*
arr = array('i', [23,45,57,60,67])
for x in arr:
  print(x)
# Out:
# 23
# 45
# 57
# 60
# 67

# %%
arr[-1]
# Out:
# 67

# %%
arr.index(57)
# Out:
# 2

# %%
# tuple: indexing
tuple = (1,2,3,4,'py')
tuple[-1]
# Out:
# 'py'

# %%
tuple.index(4)
# Out:
# 3

# %%
# set: indexing, set is having nonsequential data.
set = {'two', 1,2,3,4,5,5,6,6}
set[-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2451/1827643538.py in <cell line: 0>()
#       1 # set: indexing, set is having nonsequential data.
#       2 set = {'two', 1,2,3,4,5,5,6,6}
# ----> 3 set[-1]
#
# TypeError: 'set' object is not subscriptable

# %%
# dictionary : indexing
dict = {'num': [1,1,1,2,3,3,'three'], 'num1': [9,8,7,6,5]}
dict['num']

# %%
dict.index('num1')

# %%
dict[-1]

# %%
import builtins
range1 = builtins.range(1,12,4)
print(range1)
for x in range1:
  print(x)

# %%
range[0]

# %%
range.index(0)

# %%
range[3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2451/3245419657.py in <cell line: 0>()
# ----> 1 range[3]
#
# TypeError: type 'range' is not subscriptable
